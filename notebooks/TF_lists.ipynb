# %%
import pandas as pd
import numpy as np
import pickle

# %%
# ENSID to gene name
infile = '../genome/hg38/hg38_ENSID_Genename_synonyms.txt.gz'
df = pd.read_csv(infile,sep='\t',usecols=[0,1])
df.replace({np.nan:'None'},inplace=True)
ID_2_GeneName = dict(zip(df['Gene stable ID'],df['Gene name']))

# load synonym to gene name dictionary
infile = '../genome/hg38/GeneName_Synonyms_dict.pkl'
with open(infile, 'rb') as f:
    Synonym_2_GeneName = pickle.load(f)

# %%
# Human tf list

infile = "../resources/The_Human_Transcription_Factors_Cell_2018.xlsx"
df = pd.read_excel(infile, sheet_name="Table S1. Related to Figure 1B", skiprows=1,index_col=0)
# rename column 3:
rename = {"Unnamed: 3": "Is TF"}
df = df.rename(columns=rename)

#df = df.loc[:,"Is TF"] == 'Yes'
TFs = set( np.sort( df.loc[df.loc[:,"Is TF"] == 'Yes',:].Name.unique() ) )

# correct gene names
to_add = set()
to_remove = set()
for g in TFs:
    if g in ID_2_GeneName.values():
        continue
    else:
        if g in Synonym_2_GeneName.keys():
            to_add.add(Synonym_2_GeneName[g])
        else:
            to_remove.add(g)
TFs = TFs.difference(to_remove).union(to_add)

# GO terms
go_terms = ['negative_regulation_of_transcription_by_RNA_polymerase_II','positive_regulation_of_transcription_by_RNA_polymerase_II','regulation_of_transcription_by_RNA_polymerase_II','transcription_cis-regulatory_region_binding']
infiles = [f'../resources/GO_terms/hg38/{f}.txt' for f in go_terms]

go_genes = set()
for f in infiles:
    with open(f,'r') as fin:
        for line in fin:
            go_genes.add(line.strip())

# correct gene names
to_add = set()
to_remove = set()
for g in go_genes:
    if g in ID_2_GeneName.values():
        continue
    else:
        if g in Synonym_2_GeneName.keys():
            to_add.add(Synonym_2_GeneName[g])
        else:
            to_remove.add(g)

go_genes = go_genes.difference(to_remove).union(to_add)

TFs = go_genes.union(set(TFs))

# save
outfile = '../resources/hg38_TFs.txt'
with open(outfile,'w') as fout:
    for g in TFs:
        fout.write(f'{g}\n')

# %%
# mouse



# Human tf list

# ENSID to gene name
infile = '../genome/mm10/mm10_ENSID_Genename_synonyms.txt.gz'
df = pd.read_csv(infile,sep='\t',usecols=[0,1])
df.replace({np.nan:'None'},inplace=True)
ID_2_GeneName = dict(zip(df['Gene stable ID'],df['Gene name']))


# load synonym to gene name dictionary
infile = '../genome/mm10/GeneName_Synonyms_dict.pkl'
with open(infile, 'rb') as f:
    Synonym_2_GeneName = pickle.load(f)

infile = "../resources/mouse_ensemble_tfs_from_lambertetal_isyes.unique.txt"
TFs = set()
with open(infile,'r') as fin:
    for line in fin:
        tf = line.strip()
        if tf in ID_2_GeneName:
            TFs.add(ID_2_GeneName[tf])
        else:
            print(f'{tf} not found in ID_2_GeneName')  

# GO terms
go_terms = ['negative_regulation_of_transcription_by_RNA_polymerase_II','positive_regulation_of_transcription_by_RNA_polymerase_II','regulation_of_transcription_by_RNA_polymerase_II','transcription_cis-regulatory_region_binding']
infiles = [f'../resources/GO_terms/mm10/{f}.txt' for f in go_terms]

go_genes = set()
for f in infiles:
    with open(f,'r') as fin:
        for line in fin:
            go_genes.add(line.strip())

# correct gene names
to_add = set()
to_remove = set()
for g in go_genes:
    if g in ID_2_GeneName.values():
        continue
    else:
        if g in Synonym_2_GeneName.keys():
            to_add.add(Synonym_2_GeneName[g])
        else:
            to_remove.add(g)

go_genes = go_genes.difference(to_remove).union(to_add)

TFs = go_genes.union(set(TFs))

# save
outfile = '../resources/hg38/TFs.txt'
with open(outfile,'w') as fout:
    for g in TFs:
        fout.write(f'{g}\n')
# Out:
# ENSMUSG00000118665 not found in ID_2_GeneName

# %%
len(go_genes)
# Out:
# 2565

# %%
len(TFs)
# Out:
# 1372

# %%
len(go_genes.union(set(TFs)))
# Out:
# 2746

# %%
infile_chip = '../resources/experimentList_v3.tab'
all_chip = pd.read_csv(infile_chip,sep='\t',header=None,usecols=[0,1,2,3,4,5,6,7,8],index_col=0)
all_chip.columns = ['genome','antigen_class','antigen','celltype_class','celltype','celltype_description','QC','title']
all_chip = all_chip[ all_chip.antigen_class=='TFs and others' ]

# %%
for genome in ['mm10','hg38']:
    print(genome)
    chip = all_chip[ all_chip.genome==genome ]
    antigen = chip.antigen.unique()

    # load gene name list
    infile = f'../genome/{genome}/{genome}_ENSID_Genename_synonyms.txt.gz'
    df = pd.read_csv(infile,sep='\t',usecols=[1])
    df.replace({np.nan:'None'},inplace=True)
    GeneName = set(df['Gene name'])

    # load synonym to gene name dictionary
    infile = f'../genome/{genome}/GeneName_Synonyms_dict.pkl'
    with open(infile, 'rb') as f:
        Synonym_2_GeneName = pickle.load(f)

    to_change = []
    not_found = []
    for g in antigen:
        if g in GeneName:
            continue
        else:
            if g in Synonym_2_GeneName.keys():
                to_change.append([g,Synonym_2_GeneName[g]])
            else:
                not_found.append(g)
    
    print(f'to change: {len(to_change)}')
    print(np.array(to_change))
    print(f'not found: {len(not_found)}')
    print(np.array(not_found))

    to_change = dict(zip(np.array(to_change)[:,0],np.array(to_change)[:,1]))

    # change gene names
    for g in to_change.keys():
        idx = chip[ chip.antigen==g ].index
        for i in idx:
            chip.at[i,'antigen'] = to_change[chip.at[i,'antigen']]
# Out:
# mm10
# to change: 12
# [['H1foo' 'H1f8']
#  ['Whsc1l1' 'Nsd3']
#  ['Cpsf3l' 'Ints11']
#  ['Fam60a' 'Sinhcaf']
#  ['INO80' 'Ino80']
#  ['Iho1' 'Ccdc36']
#  ['Mkl1' 'Mrtfa']
#  ['Mkl2' 'Mrtfb']
#  ['Zfp191' 'Zfp24']
#  ['Fam208a' 'Tasor']
#  ['Hdgfrp2' 'Hdgfl2']
#  ['Cirh1a' 'Utp4']]
# not found: 25
# ['Epitope tags' 'Meiosin' 'GFP' 'Biotin' '5-hmC' 'ADP-ribose'
#  'Crotonyl lysine' '5-mC' 'DNA-RNA hybrid' 'RFP' 'Cas9' 'BrdU' 'CEBPA'
#  '8-Hydroxydeoxyguanosine' 'HBx' 'Lysin homocysteine' 'Succinyllysine'
#  'O-GlcNAc' 'AML1-ETO' 'Fo' 'Dendra2' 'Hdgf2' 'Propionyllysine'
#  'Butyryllysine' 'RAF1']
# hg38
# to change: 32
# [['T' 'TBXT']
#  ['CCDC101' 'SGF29']
#  ['ARNTL' 'BMAL1']
#  ['ZNF788' 'ZNF788P']
#  ['ZCCHC11' 'TUT4']
#  ['RNF219' 'OBI1']
#  ['ZNF720' 'KRBOX5']
#  ['PHB' 'PHB1']
#  ['WHSC1' 'NSD2']
#  ['C11orf53' 'POU2AF2']
#  ['ZUFSP' 'ZUP1']
#  ['CPSF3L' 'INTS11']
#  ['WDR61' 'SKIC8']
#  ['C7orf26' 'INTS15']
#  ['MINA' 'RIOX2']
#  ['TCEB3C' 'ELOA3P']
#  ['MRE11A' 'MRE11']
#  ['GUCY1B3' 'GUCY1B1']
#  ['ZSCAN5D' 'ZSCAN5DP']
#  ['MGEA5' 'OGA']
#  ['WHSC1L1' 'NSD3']
#  ['PTRF' 'CAVIN1']
#  ['FAM208A' 'TASOR']
#  ['ZNF645' 'CBLL2']
#  ['ARNTL2' 'BMAL2']
#  ['GLTSCR1' 'BICRA']
#  ['C10orf12' 'LCOR']
#  ['C17orf96' 'EPOP']
#  ['ASUN' 'INTS13']
#  ['TCEB3' 'ELOA']
#  ['MKL1' 'MRTFA']
#  ['MKL2' 'MRTFB']]
# not found: 46
# ['MLL-AF6' 'Epitope tags' 'GFP' 'MethylCap' 'pFM2' 'HIV Tat' 'EBNA2'
#  'HDGF2' 'AML1-ETO' 'PAD2' 'G-quadruplex' 'MCPV ST' 'Biotin' 'AAV Rep68'
#  'DEC1' 'KSHV LANA' '5-hmC' '5-mC' 'HIV1 tat' 'Crotonyllysine' 'HHV UL87'
#  'STRA13' 'EBNA1' 'BrdU' '8-Hydroxydeoxyguanosine' 'MLL-AF4' 'MLL-AF10'
#  'TAZ' 'DNA-RNA hybrid' 'RTA' 'Cpf1' 'EBV-ZEBRA'
#  'Cyclobutane pyrimidine dimers' 'RNA-DNA hybrids' 'O-GlcNAc' 'TRF2'
#  'EBNA3' 'Hepatitis B Virus X antigen' 'Pan-acetyllysine' 'Cas9' 'TRP47'
#  'BMI' 'SVS-1' 'HBcAg' 'RDme1' 'VSV-G']

# %%
chip
# Out:
#            genome   antigen_class  antigen  celltype_class  \
# 0
# DRX000550    hg38  TFs and others    PARK7          Neural
# DRX001460    hg38  TFs and others  MLL-AF6           Blood
# DRX002911    hg38  TFs and others    LRIF1          Neural
# DRX002912    hg38  TFs and others   SMCHD1          Neural
# DRX002915    hg38  TFs and others   SMCHD1          Neural
# ...           ...             ...      ...             ...
# SRX9975616   hg38  TFs and others    SMC1A            Bone
# SRX9977681   hg38  TFs and others    LARP7  Cardiovascular
# SRX9977682   hg38  TFs and others   TRIM28  Cardiovascular
# SRX9989504   hg38  TFs and others      GFP          Neural
# SRX9989505   hg38  TFs and others      GFP          Neural
#
#                            celltype  \
# 0
# DRX000550                   SH-SY5Y
# DRX001460                      ML-2
# DRX002911               hTERT RPE-1
# DRX002912               hTERT RPE-1
# DRX002915               hTERT RPE-1
# ...                             ...
# SRX9975616                    A-673
# SRX9977681                    HUVEC
# SRX9977682                    HUVEC
# SRX9989504  Neural progenitor cells
# SRX9989505  Neural progenitor cells
#
#                                          celltype_description  \
# 0
# DRX000550   Primary Tissue=Brain|Tissue Diagnosis=Neurobla...
# DRX001460   Primary Tissue=Bone Marrow|Tissue Diagnosis=Le...
# DRX002911          Primary Tissue=Eye|Tissue Diagnosis=Normal
# DRX002912          Primary Tissue=Eye|Tissue Diagnosis=Normal
# DRX002915          Primary Tissue=Eye|Tissue Diagnosis=Normal
# ...                                                       ...
# SRX9975616  Primary Tissue=Skeletal Muscle|Tissue Diagnosi...
# SRX9977681  Primary Tissue=Umbilical Cord|Tissue Diagnosis...
# SRX9977682  Primary Tissue=Umbilical Cord|Tissue Diagnosis...
# SRX9989504                                                NaN
# SRX9989505                                                NaN
#
#                                   QC  \
# 0
# DRX000550      8039428,33.4,42.5,165
# DRX001460     30648533,94.0,11.0,477
# DRX002911    39861269,96.9,75.4,1489
# DRX002912    38935687,96.2,63.0,1817
# DRX002915     32681797,97.5,45.0,992
# ...                              ...
# SRX9975616  94607697,96.6,12.7,68149
# SRX9977681     15598222,0.0,59.1,296
# SRX9977682     13137802,0.0,15.4,848
# SRX9989504    10744456,95.8,16.3,568
# SRX9989505    10664955,95.3,15.7,566
#
#                                                         title
# 0
# DRX000550   Genome-wide analysis of DJ-1-binding regions o...
# DRX001460   Comprehensive identification and characterizat...
# DRX002911                        HBiX1 ChIP-seq in hTERT-RPE1
# DRX002912                       SMCHD1 ChIP-seq in hTERT-RPE1
# DRX002915   SMCHD1 ChIP-seq in hTERT-RPE1 treated with HBi...
# ...                                                       ...
# SRX9975616  GSM5049899: SMC1A on A673 STAG2 KO [BA A673 ST...
# SRX9977681  GSM5050367: LARP7 ChIPSeq; Homo sapiens; ChIP-Seq
# SRX9977682  GSM5050368: TRIM28 ChIPSeq; Homo sapiens; ChIP...
# SRX9989504    GSM5057432: IP NS5 rep1; Homo sapiens; ChIP-Seq
# SRX9989505    GSM5057433: IP NS5 rep2; Homo sapiens; ChIP-Seq
#
# [32447 rows x 8 columns]

# %%
print( chip.loc[chip.antigen =='ARNTL'] )
print( chip.loc[chip.antigen =='BMAL1'] )
# Out:
# Empty DataFrame
# Columns: [genome, antigen_class, antigen, celltype_class, celltype, celltype_description, QC, title]
# Index: []
#             genome   antigen_class antigen celltype_class       celltype  \
# 0
# SRX1034771    hg38  TFs and others   BMAL1           Bone           U2OS
# SRX10475531   hg38  TFs and others   BMAL1          Liver         Hep G2
# SRX10475532   hg38  TFs and others   BMAL1          Liver         Hep G2
# SRX10829233   hg38  TFs and others   BMAL1           Bone           U2OS
# SRX10829234   hg38  TFs and others   BMAL1           Bone           U2OS
# ...            ...             ...     ...            ...            ...
# SRX8151645    hg38  TFs and others   BMAL1      Adipocyte  Preadipocytes
# SRX8151646    hg38  TFs and others   BMAL1      Adipocyte  Preadipocytes
# SRX8151647    hg38  TFs and others   BMAL1      Adipocyte  Preadipocytes
# SRX8151648    hg38  TFs and others   BMAL1      Adipocyte  Preadipocytes
# SRX8151649    hg38  TFs and others   BMAL1      Adipocyte  Preadipocytes
#
#                                           celltype_description  \
# 0
# SRX1034771   Tissue=bone|Lineage=mesoderm|Description=osteo...
# SRX10475531  Primary Tissue=Liver|Tissue Diagnosis=Carcinom...
# SRX10475532  Primary Tissue=Liver|Tissue Diagnosis=Carcinom...
# SRX10829233  Tissue=bone|Lineage=mesoderm|Description=osteo...
# SRX10829234  Tissue=bone|Lineage=mesoderm|Description=osteo...
# ...                                                        ...
# SRX8151645                                                 NaN
# SRX8151646                                                 NaN
# SRX8151647                                                 NaN
# SRX8151648                                                 NaN
# SRX8151649                                                 NaN
#
#                                    QC  \
# 0
# SRX1034771    18258406,97.7,15.4,1682
# SRX10475531  40911144,88.9,18.8,12833
# SRX10475532  37647123,85.5,17.4,10365
# SRX10829233  71348747,93.7,46.9,22023
# SRX10829234  72865668,92.0,40.7,27379
# ...                               ...
# SRX8151645    43778398,93.9,25.6,4143
# SRX8151646    38152298,96.8,25.3,4701
# SRX8151647    38515763,84.8,28.7,3943
# SRX8151648    35576504,89.1,23.7,2819
# SRX8151649    35886084,92.1,25.8,4489
#
#                                                          title
# 0
# SRX1034771   GSM1692868: ChIP hBMAL1 Chip-seq; Homo sapiens...
# SRX10475531  GSM5214357: TF ChIP-seq from HepG2 (ENCLB159WU...
# SRX10475532  GSM5214358: TF ChIP-seq from HepG2 (ENCLB292VM...
# SRX10829233  GSM5288539: U2OS GFP BMAL1 ChIPseq 1; Homo sap...
# SRX10829234  GSM5288540: U2OS GFP BMAL1 ChIPseq 2; Homo sap...
# ...                                                        ...
# SRX8151645   GSM4489524: ObeseClassIII2; Homo sapiens; ChIP...
# SRX8151646   GSM4489525: ObeseClassIII3; Homo sapiens; ChIP...
# SRX8151647      GSM4489526: Non-Obese1; Homo sapiens; ChIP-Seq
# SRX8151648      GSM4489527: Non-Obese2; Homo sapiens; ChIP-Seq
# SRX8151649      GSM4489528: Non-Obese3; Homo sapiens; ChIP-Seq
#
# [63 rows x 8 columns]

# %%
chip.loc[chip.antigen =='ARNTL']
g = 'ARNTL'
idx = chip.loc[chip.antigen == g]
chip.loc[idx,'antigen'] = to_change[g]
chip.loc[chip.antigen =='ARNTL']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[250], line 4
#       2 g = 'ARNTL'
#       3 idx = chip.loc[chip.antigen == g]
# ----> 4 chip.loc[idx,'antigen'] = to_change[g]
#       5 chip.loc[chip.antigen =='ARNTL']
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexing.py:907, in _LocationIndexer.__setitem__(self, key, value)
#     905     maybe_callable = com.apply_if_callable(key, self.obj)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907 indexer = self._get_setitem_indexer(key)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexing.py:774, in _LocationIndexer._get_setitem_indexer(self, key)
#     771 if isinstance(key, tuple):
#     772     with suppress(IndexingError):
#     773         # suppress "Too many indexers"
# --> 774         return self._convert_tuple(key)
#     776 if isinstance(key, range):
#     777     # GH#45479 test_loc_setitem_range_key
#     778     key = list(key)
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexing.py:989, in _LocationIndexer._convert_tuple(self, key)
#     985 @final
#     986 def _convert_tuple(self, key: tuple) -> tuple:
#     987     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     988     self._validate_key_length(key)
# --> 989     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     990     return tuple(keyidx)
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexing.py:989, in <listcomp>(.0)
#     985 @final
#     986 def _convert_tuple(self, key: tuple) -> tuple:
#     987     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     988     self._validate_key_length(key)
# --> 989     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     990     return tuple(keyidx)
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexing.py:1522, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1520         return key
#    1521     else:
# -> 1522         return self._get_listlike_indexer(key, axis)[1]
#    1523 else:
#    1524     try:
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/chip/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([                                                                      ('g', 'e', 'n', 'o', 'm', 'e'),\n                                          ('a', 'n', 't', 'i', 'g', 'e', 'n', '_', 'c', 'l', 'a', 's', 's'),\n                                                                        ('a', 'n', 't', 'i', 'g', 'e', 'n'),\n                                     ('c', 'e', 'l', 'l', 't', 'y', 'p', 'e', '_', 'c', 'l', 'a', 's', 's'),\n                                                                   ('c', 'e', 'l', 'l', 't', 'y', 'p', 'e'),\n       ('c', 'e', 'l', 'l', 't', 'y', 'p', 'e', '_', 'd', 'e', 's', 'c', 'r', 'i', 'p', 't', 'i', 'o', 'n'),\n                                                                                                 ('Q', 'C'),\n                                                                                  ('t', 'i', 't', 'l', 'e')],\n      dtype='object', name=0)] are in the [index]"

# %%
infile = '../resources/hg38/TF_list.txt'
with open(infile,'r') as f:
    TFs = [tf.strip() for tf in f.readlines()]

# %%
TFs
# Out:
# ['NRIP2',
#  'ZNF578',
#  'MYRF',
#  'TRIM29',
#  'TEAD2',
#  'ASH2L',
#  'ST3GAL4',
#  'CHP2',
#  'SSBP3',
#  'ZNF681',
#  'RBBP8',
#  'HOXD3',
#  'ZNF787',
#  'ZNF576',
#  'CRLF3',
#  'BUD31',
#  'MBD3',
#  'ZNF23',
#  'SOX4',
#  'RIGI',
#  'HMX1',
#  'JMY',
#  'ZNF792',
#  'LARP7',
#  'SNAPC5',
#  'TXNIP',
#  'PTOV1',
#  'DMRTA1',
#  'ZNF492',
#  'ZNF287',
#  'DMRT3',
#  'CEBPZ',
#  'PGBD1',
#  'TLX3',
#  'JAZF1',
#  'MSX2',
#  'IRF7',
#  'XRCC6',
#  'EMC2',
#  'SEPTIN3',
#  'KLF6',
#  'ZNF77',
#  'WAS',
#  'PTMA',
#  'NKX3-2',
#  'IRF2',
#  'ABLIM3',
#  'MBD3L2B',
#  'ZNF253',
#  'RPAP2',
#  'MED5',
#  'STAT2',
#  'TFAP2E',
#  'CBFB',
#  'NUCKS1',
#  'ZNF397',
#  'RB1',
#  'THAP10',
#  'NACC1',
#  'TFDP1',
#  'BAHD1',
#  'PI',
#  'CDX4',
#  'LIN54',
#  'MAGEB17',
#  'ATM',
#  'TAL2',
#  'TARBP1',
#  'ZSCAN5DP',
#  'ZSCAN9',
#  'CRK',
#  'ZNF239',
#  'TBL1XR1',
#  'ZNF229',
#  'SNAPC4',
#  'SUMO2',
#  'SP2',
#  'HIF3A',
#  'GLMP',
#  'ZBTB16',
#  'ZNF763',
#  'CCNT2',
#  'PLK1',
#  'MLX',
#  'ZNF500',
#  'ZNF490',
#  'CUX2',
#  'SATB2',
#  'CCNL1',
#  'TRAFD1',
#  'ZNF665',
#  'ZNF355P',
#  'ZNF415',
#  'NFIB',
#  'ARM',
#  'ZNF841',
#  'YEATS2',
#  'ARID2',
#  'LEFTY1',
#  'TCF3',
#  'RGMA',
#  'ZNF524',
#  'ZHX2',
#  'ASCL4',
#  'ZBTB1',
#  'CREB5',
#  'RFX1',
#  'TSC22D3',
#  'GREM1',
#  'DACH',
#  'PTF1A',
#  'TPRXL',
#  'HTR2A',
#  'ZNF585B',
#  'CDKN2A',
#  'RORB',
#  'HMG20A',
#  'ASXL1',
#  'ZNF596',
#  'UCP1',
#  'BHLHE41',
#  'RBBP7',
#  'ZBTB39',
#  'NR4A2',
#  'ZNF283',
#  'MEF2D',
#  'NR1I3',
#  'THAP7',
#  'ZBTB49',
#  'ZNF677',
#  'ERCC6',
#  'OVOL2',
#  'IL2',
#  'ZNF70',
#  'ELK3',
#  'ZNF705EP',
#  'PKNOX1',
#  'CD40',
#  'PRDM10',
#  'DEAF1',
#  'HCFC2',
#  'ZNF30',
#  'MAGEA8',
#  'ZNF45',
#  'JAK2',
#  'ING1',
#  'ELP2',
#  'ZSCAN32',
#  'HMGB1P1',
#  'PDCD6-AHRR',
#  'HMGN3',
#  'ZNF879',
#  'ZC3H12A',
#  'ZNF768',
#  'AP3D1',
#  'SP140',
#  'SRF',
#  'IL11',
#  'DUX4L9',
#  'ZZZ3',
#  'FOXL1',
#  'SIX1',
#  'ZNF829',
#  'CDK8',
#  'EBF1',
#  'ZNF765',
#  'MAGEB18',
#  'SMARCA4',
#  'ZBTB4',
#  'SMIM7',
#  'MAPK1',
#  'PRDM14',
#  'KDM5B',
#  'ZIM2',
#  'MEIS1',
#  'SARS1',
#  'ZNF80',
#  'RFC1',
#  'TLE5',
#  'TP73',
#  'NPAS3',
#  'MKL2',
#  'ZNF343',
#  'DUSP22',
#  'ARNT2',
#  'RIPPLY1',
#  'USF3',
#  'XPA',
#  'LHX5',
#  'ZBTB17',
#  'ZNF212',
#  'VHL',
#  'DUX4L6',
#  'ZNF568',
#  'NFE2L2',
#  'CRYM',
#  'NFATC1',
#  'CSRNP2',
#  'FADD',
#  'ECD',
#  'FOXK2',
#  'UBE2D3',
#  'REPIN1',
#  'TERF1',
#  'ZNF487',
#  'MIR9-1HG',
#  'IGBP1',
#  'RAI1',
#  'CHOP',
#  'HOXA5',
#  'ZKSCAN5',
#  'KLF1',
#  'FOXF2',
#  'MADH2',
#  'PIAS1',
#  'DLX6',
#  'TADA2B',
#  'ZFHX4',
#  'ZNF704',
#  'EID2',
#  'WASL',
#  'CALCOCO1',
#  'FEZF2',
#  'GABPB1',
#  'EPOP',
#  'ZNF583',
#  'HAVCR1',
#  'APP',
#  'CSRNP3',
#  'ZNF367',
#  'ZNF232',
#  'ATBF1',
#  'MDM4',
#  'UBE2I',
#  'MACC1',
#  'GTF2I',
#  'LMX1A',
#  'HIVEP1',
#  'SIX4',
#  'GLYR1',
#  'MAGEC3',
#  'SUV39H1',
#  'SPIC',
#  'PARP1',
#  'GSC2',
#  'HOXB13',
#  'IHH',
#  'ZNF284',
#  'ZNF600',
#  'ZNF611',
#  'ZSCAN29',
#  'CREB3L3',
#  'CYTL1',
#  'ZFX',
#  'IL23A',
#  'MED14',
#  'ZNF473',
#  'SMARCC1',
#  'CTR9',
#  'CRY1',
#  'RBPJL',
#  'ANK3',
#  'L3MBTL4',
#  'ZNF136',
#  'SOX7',
#  'TCF24',
#  'NPY6R',
#  'JPH2',
#  'PAX9',
#  'FOXD4L1',
#  'ESR1',
#  'ING2',
#  'HNF4G',
#  'EHMT1',
#  'LHX4',
#  'PARP15',
#  'HOXA3',
#  'BYE1',
#  'MAGEA2',
#  'CUL3',
#  'ZNF805',
#  'EBF3',
#  'HTATIP2',
#  'FASLG',
#  'ZXDB',
#  'INO80',
#  'HDAC8',
#  'GBX1',
#  'H1-3',
#  'MIER2',
#  'ZNF876P',
#  'ZNF34',
#  'PFKM',
#  'RFX5',
#  'FGF8',
#  'ACVR2A',
#  'ITGB1BP1',
#  'ELL',
#  'ZNF200',
#  'SAP130',
#  'RIPK1',
#  'BRPF1',
#  'EGFR',
#  'ARID5A',
#  'NOTCH1',
#  'OLIG2',
#  'ZNF788',
#  'PRDM2',
#  'elk1',
#  'ZNF667',
#  'ZNF823',
#  'PIK3R1',
#  'YY1',
#  'PPARG',
#  'SOX15',
#  'ZNF774',
#  'ZBTB45',
#  'ZNF43',
#  'GATA5',
#  'POLE3',
#  'ZNF575',
#  'TAF13',
#  'WNT10B',
#  'E4F1',
#  'CAMTA2',
#  'NKX2-6',
#  'CKS2',
#  'THAP12',
#  'ZFAT',
#  'SPN',
#  'RUNX3',
#  'CREBBP',
#  'TLX2',
#  'FGF1',
#  'ONECUT3',
#  'IER5',
#  'EPAS1',
#  'ANKRD1',
#  'STRA8',
#  'ELANE',
#  'ZNF418',
#  'PROP1',
#  'MCPH1',
#  'HDAC10',
#  'PRDM8',
#  'FOXH1',
#  'KLF14',
#  'HTR2',
#  'ZNF850',
#  'BHLHE40',
#  'ZNF543',
#  'TOP2A',
#  'ZNF71',
#  'ZNF711',
#  'JMJD1C',
#  'ZNF761',
#  'ZNF320',
#  'ZNF20',
#  'NFATC2IP',
#  'IRF2BP2',
#  'WDR5',
#  'UCN',
#  'CREBZF',
#  'SIRT1',
#  'TRIAP1',
#  'HES7',
#  'ZNF561',
#  'TBX10',
#  'POU3F3',
#  'ZNF529',
#  'STAT6',
#  'CD81',
#  'FOXR1',
#  'P2RY1',
#  'RNF20',
#  'LMX1B',
#  'TCF20',
#  'TBX3',
#  'KLF3',
#  'MED8',
#  'ZNF716',
#  'HIVEP2',
#  'ZNF641',
#  'DZIP1',
#  'ANK1',
#  'FHOD1',
#  'GATA6',
#  'CDK5RAP2',
#  'TFEB',
#  'MAFK',
#  'ZFP36',
#  'FOXD4',
#  'RNF14',
#  'EBF2',
#  'PER',
#  'ZFP37',
#  'PCID2',
#  'IKBKB',
#  'SFN',
#  'SP110',
#  'LMO7',
#  'ZNF112',
#  'RALY',
#  'MLIP',
#  'ZBTB3',
#  'KAT6B',
#  'HOXB9',
#  'AKT1',
#  'BRD4',
#  'NAMPT',
#  'MYT1L',
#  'SKOR1',
#  'ARNTL',
#  'NEUROG1',
#  'RBM10',
#  'TP53',
#  'DDX17',
#  'GTF2H2C',
#  'RELA',
#  'HES6',
#  'CDK13',
#  'SUPT20HL2',
#  'ZNF705E',
#  'MTA1',
#  'IRF2BP1',
#  'RBL1',
#  'TNIP2',
#  'KAT8',
#  'DPRX',
#  'ZNF322',
#  'STZ',
#  'BRD8',
#  'HLF',
#  'ZSCAN5B',
#  'PRKD1',
#  'KAT7',
#  'NOD2',
#  'CCDC160',
#  'BMAL2',
#  'DDX3X',
#  'ZNF658',
#  'REL',
#  'NBPF10',
#  'TIGD1',
#  'WNT7A',
#  'DBX1',
#  'CRY2',
#  'HMX3',
#  'CRYGFP',
#  'FOXG1',
#  'ARMCX3',
#  'NEPNP',
#  'ZNF416',
#  'ZNF771',
#  'YBX3',
#  'AJUBA',
#  'BNC2',
#  'PHP',
#  'ZNF419',
#  'MAD2L2',
#  'FOXM1',
#  'CCNL2',
#  'IFNG',
#  'PHIP',
#  'ETV7',
#  'ZNF385C',
#  'EED',
#  'H3C15',
#  'OVOL1',
#  'RCC1',
#  'TRIM3',
#  'PCBP1',
#  'ST18',
#  'HES2',
#  'ZNF506',
#  'RIPPLY2',
#  'RUNX1',
#  'ELF2',
#  'TIGD5',
#  'HDAC5',
#  'FOXJ3',
#  'BRF2',
#  'ZNF614',
#  'ADAM10',
#  'ZNF417',
#  'XRN2',
#  'MOSPD1',
#  'ETS2',
#  'IL10',
#  'PARP9',
#  'ZNF431',
#  'NCOR1',
#  'ZNF184',
#  'ZNF784',
#  'ZNF777',
#  'HMX2',
#  'NR2C1',
#  'HIC2',
#  'ADNP',
#  'ZNF687',
#  'SWC4',
#  'ARID3A',
#  'ZBED9',
#  'RLIM',
#  'ZNF225',
#  'ZNF747',
#  'CTDSP1',
#  'TEF',
#  'ZNF680',
#  'ZNF385A',
#  'ZNF737',
#  'FBP1',
#  'ACTR3',
#  'DMRT2',
#  'ZNF446',
#  'ZNF140',
#  'DUXA',
#  'ZNF837',
#  'TRERF1',
#  'TTC5',
#  'ZNF615',
#  'LPIN2',
#  'OTX1',
#  'SNW1',
#  'RBM14',
#  'PRDM9',
#  'ZNF101',
#  'SRB7',
#  'NR2C2',
#  'CBX2',
#  'TCP10L',
#  'INSM1',
#  'ZNF767P',
#  'NR2F1',
#  'ATF7',
#  'MED31',
#  'ZNF32',
#  'ZNF692',
#  'ZNF653',
#  'CTNNBIP1',
#  'SP8',
#  'ITGA6',
#  'DNMT3L',
#  'KLF4',
#  'ZNF764',
#  'ATF2',
#  'NEUROD4',
#  'ARID1A',
#  'GPER1',
#  'MED19',
#  'ZNF767',
#  'TEAD1',
#  'ZNF331',
#  'WWC3',
#  'MLLT6',
#  'PDE3A',
#  'FKH1',
#  'ZNF827',
#  'ZBTB46',
#  'HOXC9',
#  'CIR1',
#  'GALR2',
#  'ACACA',
#  'ZNF713',
#  'ZNF311',
#  'ZNF804A',
#  'ZNF594',
#  'ABRA',
#  'MCRS1',
#  'HMG1',
#  'DDN',
#  'ZNF579',
#  'BRIP1',
#  'PPP3CA',
#  'AEBP2',
#  'NRF1',
#  'MTDH',
#  'PA2G4',
#  'FEZL',
#  'ABL1',
#  'HAT1',
#  'SAP18',
#  'SNAI3',
#  'RAX2',
#  'XRN1',
#  'PRDM6',
#  'CSRP3',
#  'ZXDC',
#  'KDM2A',
#  'HSFY2',
#  'ZSCAN21',
#  'ZNF554',
#  'NR5A1',
#  'HES4',
#  'OGG1',
#  'SCRT2',
#  'H1-4',
#  'SAFB',
#  'CREM',
#  'ZNF620',
#  'SEBOX',
#  'WNT8A',
#  'ISX',
#  'ACTL6B',
#  'TIPARP',
#  'TCFL5',
#  'CCDC169-SOHLH2',
#  'MXD1',
#  'RARA',
#  'BARX1',
#  'ZSCAN23',
#  'ID3',
#  'ONECUT1',
#  'YAP1',
#  'USP2',
#  'DNAJC17',
#  'MC1R',
#  'AKAP8',
#  'ZNF268',
#  'ACTL6A',
#  'ZNF160',
#  'BATF3',
#  'H1-2',
#  'PCGF6',
#  'CXXC4',
#  'SEP1',
#  'ZNF398',
#  'SNCA',
#  'RIF1',
#  'CITED2',
#  'ZSCAN25',
#  'LIME1',
#  'BCL11B',
#  'ZBTB41',
#  'PAX4',
#  'EGLN1',
#  'TERF2',
#  'ENG',
#  'DNAJB1',
#  'NOTCH2',
#  'ZNF541',
#  'POU5F2',
#  'RUNX2',
#  'NFYA',
#  'ZNF662',
#  'ZBED5',
#  'ZNF724',
#  'ZNF273',
#  'SREBF1',
#  'ZNF423',
#  'PWWP2A',
#  'BHLHA9',
#  'Zfp128',
#  'MAGEB1',
#  'PKD2',
#  'NKX6-1',
#  'RBBP4',
#  'CRF1',
#  'C11orf95',
#  'ADIRF',
#  'CHD4',
#  'SIN3B',
#  'CHCHD2P9',
#  'TNKS',
#  'MED12',
#  'ZNF432',
#  'ZNF467',
#  'ZNF705B',
#  'ZNF117',
#  'DDX20',
#  'ASH1L',
#  'ZIC1',
#  'SIRT6',
#  'ZNF840P',
#  'FOXB1',
#  'TRIM24',
#  'TP53BP1',
#  'ZUFSP',
#  'PIAS4',
#  'ZBTB7B',
#  'FAM58A',
#  'BICRAL',
#  'AKAP8L',
#  'ZFP57',
#  'NEUROG3',
#  'ZNF35',
#  'ZNF574',
#  'BHLHE23',
#  'PRRX2',
#  'ZNF843',
#  'TGIF2',
#  'LRRFIP1',
#  'SMARCD2',
#  'RORC',
#  'FOXD3',
#  'HOXA10',
#  'TRIM28',
#  'CXorf23',
#  'LTF',
#  'TAF1C',
#  'OBF1',
#  'PAXBP1',
#  'NODAL',
#  'SAMD7',
#  'RTF1',
#  'PXMP4',
#  'GATA2',
#  'ZMYM5',
#  'DMBX1',
#  'ZNF660',
#  'CELA1',
#  'ATF5',
#  'ZNF395',
#  'FOXD2',
#  'TDG',
#  'ASB18',
#  'SMURF2',
#  'ZNF616',
#  'ELA2',
#  'GDNF',
#  'MYBBP1A',
#  'RBBP5',
#  'MED16',
#  'ZNF131',
#  'ARID4B',
#  'ZHX1',
#  'TAL1',
#  'ZNF14',
#  'ZNF48',
#  'GTF2F2',
#  'E2F6',
#  'KAT5',
#  'GZF1',
#  'USP22',
#  'HOXD11',
#  'ZBTB40',
#  'ATP2B4',
#  'CCNE1',
#  'MAGEF1',
#  'P2RX2',
#  'MEOX1',
#  'SAP30',
#  'ZBTB14',
#  'TAF10',
#  'HOXB3',
#  'ZNF100',
#  'ZNF234',
#  'KLF12',
#  'HDAC1',
#  'PLK3',
#  'BRF1',
#  'PDCD6',
#  'PPP1R13L',
#  'GLO1',
#  'PRR12',
#  'ZBTB6',
#  'TIGD6',
#  'FHL5',
#  'TBL1X',
#  'CDX2',
#  'HDGF',
#  'ZNF552',
#  'COPS5',
#  'WNT2',
#  'ZNF264',
#  'ZNF483',
#  'SHH',
#  'HAVCR2',
#  'GADD45A',
#  'ZNF626',
#  'MIER3',
#  'HEYL',
#  'NKAPL',
#  'VAX2',
#  'HSF1',
#  'HSF2',
#  'ONECUT2',
#  'HDAC6',
#  'ZNF726',
#  'NR4A3',
#  'NKX2.5',
#  'MRGBP',
#  'ZSCAN18',
#  'USP3',
#  'TBX5',
#  'PAX5',
#  'PCNA',
#  'GATAD2B',
#  'NEDD4',
#  'POGK',
#  'IRX2',
#  'ZSCAN10',
#  'ZFP1',
#  'ZNF496',
#  'MEF2B',
#  'YEATS4',
#  'NFYB',
#  'NPAS4',
#  'MAFF',
#  'ZNF670',
#  'HESX1',
#  'SP1',
#  'ZNF22',
#  'FOXO3B',
#  'ATRX',
#  'RPL23',
#  'MTERF4',
#  'SP7',
#  'ING3',
#  'CHD7',
#  'SALL4',
#  'ZNF518A',
#  'HNRNPK',
#  'P2',
#  'ZNF281',
#  'PSMG1',
#  'ETV1',
#  'IFT74',
#  'POU3F4',
#  'ZNF454',
#  'PAX7',
#  'DPF1',
#  'TAF12',
#  'RCOR1',
#  'ZNF99',
#  'SPZ1',
#  'EHF',
#  'YES1',
#  'NRIP1',
#  'HSFX3',
#  'HAX1',
#  'RVB1',
#  'RBMX',
#  'TBK1',
#  'ZNF699',
#  'NLRC5',
#  'TPRX2',
#  'ZNF658B',
#  'MAGEL2',
#  'SLC9A1',
#  'ZKSCAN3',
#  'AKIRIN2',
#  'ZNF701',
#  'NR3C2',
#  'ZNF628',
#  'PBX3',
#  'IRF4',
#  'NR1D2',
#  'MKRN2',
#  'IFI16',
#  'ZNF718',
#  'GPBP1',
#  'STOX2',
#  'ZNF213',
#  'RPLP2',
#  'CC2D1B',
#  'ELL2',
#  'ZNF674',
#  'ANKZF1',
#  'ZNF705D',
#  'PTPRN',
#  'BCL9',
#  'MED23',
#  'HOXA6',
#  'MYT1',
#  'NTN1',
#  'EEA1',
#  'PSEN1',
#  'ZFP92',
#  'LDB1',
#  'MECP2',
#  'SOX8',
#  'RHOXF2B',
#  'CRX',
#  'MED9',
#  'CTDP1',
#  'POGZ',
#  'HGF',
#  'CTCFL',
#  'AMBRA1',
#  'MESP2',
#  'ZBTB8A',
#  'NLRP3',
#  'TAGLN3',
#  'BACH1',
#  'ABHD14B',
#  'MED22',
#  'MAGEB3',
#  'MYBL1',
#  'ZNF252',
#  'ANHX',
#  'RFX3',
#  'ZNF793',
#  'NRARP',
#  'NKX2-5',
#  'HIRA',
#  'NR1D1',
#  'CycC',
#  'LMO1',
#  'ZNF546',
#  'ZEB1',
#  'ECM1',
#  'SNAPC2',
#  'FOXO6',
#  'CTDSPL2',
#  'CRTC2',
#  'SGSM2',
#  'RIT2',
#  'ZFY',
#  'ZNF33A',
#  'TBXT',
#  'SAFB2',
#  'ZBTB2',
#  'LAT2',
#  'EP300',
#  'GSK3A',
#  'IRF3',
#  'HELT',
#  'ZNF573',
#  'AIRE',
#  'HOXA11',
#  'TIGD2',
#  'FOXD4L3',
#  'BTG2',
#  'ZNF318',
#  'SP100',
#  'CDK2AP1',
#  'MAPK3',
#  'FOSB',
#  'RREB1',
#  'SIX2',
#  'SDR16C5',
#  'PSMC3',
#  'UBTF',
#  'MED20',
#  'HEXIM1',
#  'ZNF345',
#  'LRP6',
#  'P',
#  'NFAT5',
#  'ZNF513',
#  'FAM200B',
#  'PKD1',
#  'EAPP',
#  'HOXC10',
#  'FERD3L',
#  'VEZF1',
#  'ESX1',
#  'MSANTD1',
#  'KANSL3',
#  'UXT',
#  'MBD2',
#  'ASXL2',
#  'SRA1',
#  'AHDC1',
#  'BPTF',
#  'ARID3C',
#  'TAF5',
#  'HSFX4',
#  'KLF13',
#  'HSBP1',
#  'BMP5',
#  'ZNF846',
#  'TWIST2',
#  'N4BP2L2',
#  'ZNF891',
#  'EDIL3',
#  'OLIG1',
#  'ASXL3',
#  'POU6F2',
#  'SIX6',
#  'TIGD4',
#  'KCMF1',
#  'ARID1B',
#  'ZFHX2',
#  'BRMS1',
#  'ZSCAN30',
#  'SSA1',
#  'GABPB2',
#  'ZNF567',
#  'CPXCR1',
#  'ZNF248',
#  'PPARA',
#  'ZNF224',
#  'ZNF559',
#  'DRD2',
#  'MAGEB4',
#  'ARHGAP35',
#  'ZNF304',
#  'RBSN',
#  'THAP5',
#  'MED24',
#  'OSR2',
#  'TP63',
#  'ZNF717',
#  'DUXB',
#  'MICAL2',
#  'JUNB',
#  'ZC3H8',
#  'E2F2',
#  ...]

# %%
on = 0
off = 0
for g in chip.antigen.unique():
    if g in np.array(TFs):
        on += 1
    else:
        off += 1

# %%
print(on,off)
# Out:
# 1426 414

# %%
infile = '../genome/mm10/mm10_ENSID_Genename_synonyms.txt.gz'
df = pd.read_csv(infile,sep='\t')
df.replace({np.nan:'None'},inplace=True)
df.drop(df.index[df['Gene Synonym']=="None"],inplace=True)
df.drop_duplicates(inplace=True)
df.drop( df.loc[df['Gene Synonym'] == df['Gene name']].index, inplace=True)

# %%
df
# Out:
#            Gene stable ID Gene name  Gene Synonym
# 0      ENSMUSG00000064372     mt-Tp          tRNA
# 1      ENSMUSG00000064372     mt-Tp      tRNA-Pro
# 2      ENSMUSG00000064372     mt-Tp     TrnP tRNA
# 3      ENSMUSG00000064371     mt-Tt          tRNA
# 4      ENSMUSG00000064371     mt-Tt      tRNA-Thr
# ...                   ...       ...           ...
# 82453  ENSMUSG00000116485   Mir7679  mmu-mir-7679
# 82459  ENSMUSG00000116523   Gm12185       Irgb2b1
# 82465  ENSMUSG00000115991     Slfn2         Shlf2
# 82474  ENSMUSG00000116327    Slfn14     LOC237890
# 82475  ENSMUSG00000116327    Slfn14     Slfn14-ps
#
# [49053 rows x 3 columns]
